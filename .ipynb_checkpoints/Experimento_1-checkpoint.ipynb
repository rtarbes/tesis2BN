# %%
import pandas as pd
import imblearn
import seaborn as sns
import BayesLib as bl
import os

from sklearn.datasets import make_classification
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import *
from sklearn.feature_selection import SelectKBest, f_classif, chi2

from collections import Counter
from numpy import where
from matplotlib import pyplot
from imblearn.over_sampling import SMOTE
#from imblearn.over_sampling import SMOTENC
#from imblearn.over_sampling import BorderlineSMOTE 
#from imblearn.over_sampling import SVMSMOTE
#from imblearn.over_sampling import ADASYN 
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

# %%
#abriendo el conjunto de datos desde un archivo CSV y asignandolo los datos al DataFrame "df"
df = pd.read_csv('dataset_b.csv', sep=';', error_bad_lines=False)

# %%
# %%capture
#Eliminando variables que no aportan al análisis
df = df.drop([
    'rut', 'usuario', 'correo', 'nombre', 'profesor', 
    'i1', 'f1', 's1', 
    'i2', 'f2', 's2',
    'i3', 'f3', 's3', 
    'i4', 'f4', 's4', 
    'i5', 'f5', 's5', 
    'i6', 'f6', 's6',
    'sol1', 'sol2', 'sol3', 'sol4',
    'tarea1', 'tarea2',
    'controles', 'np', 'examen'], axis=1)

# %%
#Estadísticas de la variable "programa"
serie = df['programa'].value_counts(normalize=True, ascending=True)*100
print(serie)

#Transformación numérica de la variable "programa"
for i in range(len(serie)):
    df["programa"] = df["programa"].str.replace(serie.index[i], str(i+1))
  
serie = df['programa'].value_counts(normalize=True, ascending=True)*100
print(serie)

df['programa'] = df['programa'].astype('int')
# Out:
# INGENIERIA INDUSTRIAL                       8.080808
# INGENIERIA CIVIL INFORMATICA               14.141414
# INGENIERIA EN COMPUTACION E INFORMATICA    37.373737
# INGENIERIA CIVIL INDUSTRIAL                40.404040
# Name: programa, dtype: float64
# 1     8.080808
# 2    14.141414
# 3    37.373737
# 4    40.404040
# Name: programa, dtype: float64

# %%
#Estadísticas de la variable "estado"
serie = df['estado'].value_counts(normalize=True, ascending=False)*100
print(serie)

#Transformacíon numérica de la variable "estado"
for i in range(len(serie)):
    df["estado"] = df["estado"].str.replace(serie.index[i], str(i))

serie = df['estado'].value_counts(normalize=True, ascending=False)*100
print(serie)

df['estado'] = df['estado'].astype('int')
# Out:
# A    75.757576
# R    24.242424
# Name: estado, dtype: float64
# 0    75.757576
# 1    24.242424
# Name: estado, dtype: float64

# %%
df = df.loc[:, ['lt', 'tt', 'pt', 'game_score', 
                'op1','op2', 'op3', 'op4', 'op5', 'op6',
                'sv1','sv2','sv3','sv4','sv5','sv6',
                'score', 'score_a', 'score_p', 'score_d', 'score_s',
                'programa', 'final', 'estado']]

# %%
binsNotas = 7
binsOtros = 5

valor_discreto = KBinsDiscretizer(n_bins=binsOtros, encode='ordinal', strategy = "kmeans").fit_transform(df[['lt']])
df[['lt']] = valor_discreto

valor_discreto = KBinsDiscretizer(n_bins=binsOtros, encode='ordinal', strategy = "kmeans").fit_transform(df[['tt']])
df[['tt']] = valor_discreto

puntaje_juego =  KBinsDiscretizer(n_bins=binsOtros, encode='ordinal', strategy = "kmeans").fit_transform(df[['pt']])
df[['pt']] = valor_discreto

puntaje_juego =  KBinsDiscretizer(n_bins=binsOtros, encode='ordinal', strategy = "kmeans").fit_transform(df[['game_score']])
df[['game_score']] = valor_discreto

nota_final =  KBinsDiscretizer(n_bins=binsNotas, encode='ordinal', strategy = "kmeans").fit_transform(df[['final']])
df[['final']] = valor_discreto

# %%
#indica cual va a ser el muestreo estratificado usando la clase "estado"
#cada fold mantiene la proporcion orignal de clases
#n_splits = el numero de experimentos a realizar
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=1) 
target = df.loc[:, 'estado'] #todas las filas de la columna "estado"

fold_no = 1
for train_index, test_index in skf.split(df, target):
    #---------------------------------------------------------------------------
    #INICIO: SECCION DE ENTRENAMIENTO
    #---------------------------------------------------------------------------
    print("INICIO DE SECCION DE ENTRENAMIENTO, FOLD: ", str(fold_no))
    
    #entrega la porción de datos que serán usados como entrenamiento
    train = df.loc[train_index,:] #todas las columnas de la fila "train_index"
         
    #aprendiendo la estructura y los parametros de la porción de datos entrenados "sobre muestrados"
    modelo = bl.Aprendizaje(train, fold_no, "TRAIN")
    
    #transformando el modelo aprendido en un dataset que pueda ser inferido
    newModel = bl.modelToDataFrame(modelo, train)

    #realizando la inferencia de los datos de entrenamiento
    probTrain = bl.probabilidadConjunta(modelo, newModel, fold_no, , "TRAIN")
            
    i = 0 #columna que queremos obtener
    lista_train = [fila[i] for fila in probTrain]

    #Metricas finales
    varAccuracy = accuracy_score(lista_train, train.loc[:, 'estado'])
    
    print('RESULTADOS DEL ENTRENAMIENTO CON SOBREMUESTREO:')
    print('===============================================')
    print('(TRAIN) Fold', str(fold_no), 'Accuracy          :', varAccuracy)  
    print('(TRAIN) Fold', str(fold_no), 'Balanced Accuracy :', balanced_accuracy_score(lista_train, train.loc[:, 'estado']))  
    print('(TRAIN) Fold', str(fold_no), 'Precision Score   :', precision_score(lista_train, train.loc[:, 'estado'], average='weighted'))  
    print('(TRAIN) Fold', str(fold_no), 'Recall Score      :', recall_score(lista_train, train.loc[:, 'estado'], average='weighted'))  
    print('(TRAIN) Fold', str(fold_no), 'ROC AUC           :', roc_auc_score(train.loc[:, 'estado'], lista_train, multi_class='ovr')) 
    print('(TRAIN) Fold', str(fold_no), 'Class Ratio       :', sum(train['estado'])/len(train['estado']))
    
    #Guardando las metricas en un archivo
    file = open('Metricas_'+str(fold_no)+'.txt', 'w')
    file.write('RESULTADOS DEL ENTRENAMIENTO CON SOBREMUESTREO:' + os.linesep)
    file.write('===============================================' + os.linesep)
    file.write('(TRAIN) Fold', str(fold_no), 'Accuracy          :', accuracy_score(lista_train, train.loc[:, 'estado']) + os.linesep)  
    file.write('(TRAIN) Fold', str(fold_no), 'Balanced Accuracy :', balanced_accuracy_score(lista_train, train.loc[:, 'estado']) + os.linesep)  
    file.write('(TRAIN) Fold', str(fold_no), 'Precision Score   :', precision_score(lista_train, train.loc[:, 'estado'], average='weighted') + os.linesep)  
    file.write('(TRAIN) Fold', str(fold_no), 'Recall Score      :', recall_score(lista_train, train.loc[:, 'estado'], average='weighted') + os.linesep)  
    file.write('(TRAIN) Fold', str(fold_no), 'ROC AUC           :', roc_auc_score(train.loc[:, 'estado'], lista_train, multi_class='ovr') + os.linesep) 
    file.write('(TRAIN) Fold', str(fold_no), 'Class Ratio       :', sum(train['estado'])/len(train['estado']) + os.linesep)
    file.close()
    
    
    print("FIN DE SECCION DE ENTRENAMIENTO, FOLD: ", str(fold_no))
    #---------------------------------------------------------------------------
    #FIN: SECCION DE ENTRENAMIENTO
    #---------------------------------------------------------------------------

    #---------------------------------------------------------------------------
    #INICIO: SECCION DE PRUEBAS
    #---------------------------------------------------------------------------
    print("INICIO DE SECCION DE PRUEBAS, FOLD: ", str(fold_no))
    
    #entrega la porción de datos que serán usados como pruebas
    test = df.loc[test_index,:] #todas las columnas de la fila "test_index"
        
    #aprendiendo la estructura y los parametros de la porción de datos de pruebas
    modelo = bl.Aprendizaje(test, fold_no, "TEST")

    #transformando el modelo aprendido en un dataset que pueda ser inferido
    newModel = bl.modelToDataFrame(modelo, test)
    
    #realizando la inferencia de los datos de prueba
    probTest = bl.probabilidadConjunta(modelo, newModel, fold_no, "TEST")
    
    ##i = 0 #columna que queremos obtener
    lista_test = [fila[i] for fila in probTest]
    
    print('RESULTADOS DEL TEST:')
    print('===============================================')
    print('(TEST) Fold', str(fold_no), 'Accuracy          :', accuracy_score(lista_test, test.loc[:, 'estado']))
    print('(TEST) Fold', str(fold_no), 'Balanced Accuracy :', balanced_accuracy_score(lista_test, test.loc[:, 'estado']))
    print('(TEST) Fold', str(fold_no), 'Precision Score   :', precision_score(lista_test, test.loc[:, 'estado'], average='weighted'))
    print('(TEST) Fold', str(fold_no), 'Recall Score      :', recall_score(lista_test, test.loc[:, 'estado'], average='weighted'))
    print('(TEST) Fold', str(fold_no), 'ROC AUC           :', roc_auc_score(test.loc[:, 'estado'], lista_test, multi_class='ovr')) 
    print('(TEST) Fold', str(fold_no), 'Class Ratio       :', sum(test['estado'])/len(test['estado']))

    #Guardando las metricas en un archivo
    file = open('Metricas_'+str(fold_no)+'.txt', 'a')
    file.write('RESULTADOS DEL TEST:' + os.linesep)
    file.write('===============================================' + os.linesep)
    file.write('(TEST) Fold', str(fold_no), 'Accuracy          :', accuracy_score(lista_test, test.loc[:, 'estado']) + os.linesep)
    file.write('(TEST) Fold', str(fold_no), 'Balanced Accuracy :', balanced_accuracy_score(lista_test, test.loc[:, 'estado']) + os.linesep)
    file.write('(TEST) Fold', str(fold_no), 'Precision Score   :', precision_score(lista_test, test.loc[:, 'estado'], average='weighted') + os.linesep)
    file.write('(TEST) Fold', str(fold_no), 'Recall Score      :', recall_score(lista_test, test.loc[:, 'estado'], average='weighted') + os.linesep)
    file.write('(TEST) Fold', str(fold_no), 'ROC AUC           :', roc_auc_score(test.loc[:, 'estado'], lista_test, multi_class='ovr') + os.linesep) 
    file.write('(TEST) Fold', str(fold_no), 'Class Ratio       :', sum(test['estado'])/len(test['estado']) + os.linesep)

    print("FIN DE SECCION DE PRUEBAS, FOLD: ", str(fold_no))
    #---------------------------------------------------------------------------
    #FIN: SECCION DE PRUEBAS
    #---------------------------------------------------------------------------

    #Cambiando de fold
    break
    #fold_no += 1
# Out:
# INICIO DE SECCION DE ENTRENAMIENTO, FOLD:  1
# [bnlearn] >Computing best DAG using [hc]
# [bnlearn] >Set scoring type at [bic]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# FILA N°: 0 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":0, "op2":1, "op3":1, "op4":1, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":9, "score_a":6, "score_p":4, "score_d":3, "score_s":3, "programa":3, "final":1.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5525 |
# +-----------+---------------+
# | estado(1) |        0.4475 |
# +-----------+---------------+
# FILA N°: 1 -> P("Estado" | [{"lt":0.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":0, "op3":1, "op4":1, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":5, "score_a":4, "score_p":2, "score_d":2, "score_s":1, "programa":4, "final":0.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:10, ?it/s]
# Finding Elimination Order: : : 0it [00:20, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6001 |
# +-----------+---------------+
# | estado(1) |        0.3999 |
# +-----------+---------------+
# FILA N°: 3 -> P("Estado" | [{"lt":2.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":0, "op3":0, "op4":1, "op5":0, "op6":0, "sv1":1, "sv2":0, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":9, "score_a":6, "score_p":4, "score_d":3, "score_s":3, "programa":4, "final":0.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6119 |
# +-----------+---------------+
# | estado(1) |        0.3881 |
# +-----------+---------------+
# FILA N°: 4 -> P("Estado" | [{"lt":0.0, "tt":2.0, "pt":2.0, "game_score":2.0, "op1":1, "op2":1, "op3":1, "op4":1, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":6, "score_a":4, "score_p":3, "score_d":2, "score_s":3, "programa":3, "final":2.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5773 |
# +-----------+---------------+
# | estado(1) |        0.4227 |
# +-----------+---------------+
# FILA N°: 5 -> P("Estado" | [{"lt":0.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":1, "op3":0, "op4":1, "op5":0, "op6":1, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":8, "score_a":4, "score_p":4, "score_d":3, "score_s":3, "programa":3, "final":0.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
#
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:10, ?it/s]
# Finding Elimination Order: : : 0it [00:30, ?it/s]
# Finding Elimination Order: : : 0it [00:50, ?it/s]
# Finding Elimination Order: : : 0it [00:40, ?it/s]
# 0it [00:10, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5505 |
# +-----------+---------------+
# | estado(1) |        0.4495 |
# +-----------+---------------+
# FILA N°: 6 -> P("Estado" | [{"lt":2.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":0, "op3":0, "op4":0, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":0, "sv6":0, "score":5, "score_a":2, "score_p":2, "score_d":2, "score_s":3, "programa":2, "final":0.0}]
# [bnlearn] >Variable Elimination..
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5174 |
# +-----------+---------------+
# | estado(1) |        0.4826 |
# +-----------+---------------+
# FILA N°: 9 -> P("Estado" | [{"lt":0.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":1, "op3":0, "op4":1, "op5":1, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":7, "score_a":5, "score_p":2, "score_d":2, "score_s":3, "programa":1, "final":0.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5000 |
# +-----------+---------------+
# | estado(1) |        0.5000 |
# +-----------+---------------+
# FILA N°: 10 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":0, "op2":1, "op3":0, "op4":0, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":6, "score_a":2, "score_p":4, "score_d":2, "score_s":1, "programa":1, "final":1.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5000 |
# +-----------+---------------+
# | estado(1) |        0.5000 |
# +-----------+---------------+
# FILA N°: 11 -> P("Estado" | [{"lt":1.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":0, "op2":0, "op3":1, "op4":0, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":7, "score_a":3, "score_p":4, "score_d":2, "score_s":3, "programa":2, "final":0.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.4903 |
# +-----------+---------------+
# | estado(1) |        0.5097 |
# +-----------+---------------+
# FILA N°: 12 -> P("Estado" | [{"lt":0.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":1, "op3":1, "op4":1, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":9, "score_a":5, "score_p":4, "score_d":3, "score_s":2, "programa":3, "final":0.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
#
# 0it [00:00, ?it/s]
#
# Finding Elimination Order: : : 0it [00:20, ?it/s]
# Finding Elimination Order: : : 0it [00:40, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5505 |
# +-----------+---------------+
# | estado(1) |        0.4495 |
# +-----------+---------------+
# FILA N°: 14 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":0, "op2":1, "op3":1, "op4":1, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":4, "score_a":3, "score_p":1, "score_d":3, "score_s":3, "programa":3, "final":1.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:10, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5525 |
# +-----------+---------------+
# | estado(1) |        0.4475 |
# +-----------+---------------+
# FILA N°: 16 -> P("Estado" | [{"lt":2.0, "tt":2.0, "pt":2.0, "game_score":2.0, "op1":0, "op2":0, "op3":0, "op4":0, "op5":0, "op6":0, "sv1":1, "sv2":0, "sv3":0, "sv4":1, "sv5":0, "sv6":0, "score":5, "score_a":4, "score_p":3, "score_d":0, "score_s":0, "programa":2, "final":2.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.4456 |
# +-----------+---------------+
# | estado(1) |        0.5544 |
# +-----------+---------------+
# FILA N°: 17 -> P("Estado" | [{"lt":0.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":0, "op2":1, "op3":1, "op4":1, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":7, "score_a":3, "score_p":4, "score_d":2, "score_s":1, "programa":3, "final":0.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5773 |
# +-----------+---------------+
# | estado(1) |        0.4227 |
# +-----------+---------------+
# FILA N°: 18 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":0, "op2":0, "op3":1, "op4":1, "op5":1, "op6":0, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":8, "score_a":5, "score_p":3, "score_d":3, "score_s":3, "programa":1, "final":1.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.4174 |
# +-----------+---------------+
# | estado(1) |        0.5826 |
# +-----------+---------------+
# FILA N°: 19 -> P("Estado" | [{"lt":1.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":0, "op2":0, "op3":0, "op4":1, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":3, "score_a":2, "score_p":2, "score_d":0, "score_s":0, "programa":3, "final":0.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
# 0it [00:00, ?it/s]
#
#
#
# 0it [00:00, ?it/s]
#
#
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:10, ?it/s]
# Finding Elimination Order: : : 0it [00:20, ?it/s]
# Finding Elimination Order: : : 0it [00:40, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.4600 |
# +-----------+---------------+
# | estado(1) |        0.5400 |
# +-----------+---------------+
# FILA N°: 20 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":1, "op2":1, "op3":1, "op4":0, "op5":0, "op6":1, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":8, "score_a":5, "score_p":3, "score_d":3, "score_s":3, "programa":1, "final":1.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5110 |
# +-----------+---------------+
# | estado(1) |        0.4890 |
# +-----------+---------------+
# FILA N°: 21 -> P("Estado" | [{"lt":2.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":1, "op2":0, "op3":0, "op4":0, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":0, "sv5":0, "sv6":1, "score":7, "score_a":5, "score_p":2, "score_d":3, "score_s":3, "programa":3, "final":1.0}]
# [bnlearn] >Variable Elimination..
# Finding Elimination Order: : : 0it [00:10, ?it/s]
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5300 |
# +-----------+---------------+
# | estado(1) |        0.4700 |
# +-----------+---------------+
# FILA N°: 22 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":0, "op2":1, "op3":0, "op4":0, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":4, "score_a":3, "score_p":3, "score_d":0, "score_s":1, "programa":3, "final":1.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5038 |
# +-----------+---------------+
# | estado(1) |        0.4962 |
# +-----------+---------------+
# FILA N°: 23 -> P("Estado" | [{"lt":1.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":1, "op2":0, "op3":0, "op4":0, "op5":0, "op6":0, "sv1":1, "sv2":0, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":7, "score_a":4, "score_p":4, "score_d":2, "score_s":2, "programa":3, "final":1.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
#
#
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:20, ?it/s]
# Finding Elimination Order: : : 0it [00:20, ?it/s]
# Finding Elimination Order: : : 0it [00:50, ?it/s]
# Finding Elimination Order: : : 0it [00:20, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5299 |
# +-----------+---------------+
# | estado(1) |        0.4701 |
# +-----------+---------------+
# FILA N°: 24 -> P("Estado" | [{"lt":0.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":1, "op3":0, "op4":1, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":0, "score":8, "score_a":5, "score_p":4, "score_d":2, "score_s":2, "programa":3, "final":0.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6226 |
# +-----------+---------------+
# | estado(1) |        0.3774 |
# +-----------+---------------+
# FILA N°: 25 -> P("Estado" | [{"lt":2.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":1, "op2":1, "op3":0, "op4":0, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":0, "sv5":1, "sv6":0, "score":6, "score_a":3, "score_p":3, "score_d":2, "score_s":2, "programa":1, "final":1.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5522 |
# +-----------+---------------+
# | estado(1) |        0.4478 |
# +-----------+---------------+
# FILA N°: 26 -> P("Estado" | [{"lt":1.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":0, "op3":0, "op4":1, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":3, "score_a":2, "score_p":0, "score_d":2, "score_s":3, "programa":4, "final":0.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6119 |
# +-----------+---------------+
# | estado(1) |        0.3881 |
# +-----------+---------------+
# FILA N°: 27 -> P("Estado" | [{"lt":2.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":0, "op3":0, "op4":0, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":0, "sv5":0, "sv6":0, "score":4, "score_a":2, "score_p":1, "score_d":2, "score_s":2, "programa":4, "final":0.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5627 |
# +-----------+---------------+
# | estado(1) |        0.4373 |
# +-----------+---------------+
# FILA N°: 29 -> P("Estado" | [{"lt":1.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":1, "op3":0, "op4":0, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":0, "sv5":0, "sv6":1, "score":6, "score_a":4, "score_p":3, "score_d":2, "score_s":2, "programa":4, "final":0.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
# 0it [00:00, ?it/s]
#
#
#
# 0it [00:00, ?it/s]
#
#
# Finding Elimination Order: : : 0it [00:30, ?it/s]
# 0it [00:10, ?it/s]
# Finding Elimination Order: : : 0it [00:50, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6489 |
# +-----------+---------------+
# | estado(1) |        0.3511 |
# +-----------+---------------+
# FILA N°: 30 -> P("Estado" | [{"lt":0.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":0, "op2":1, "op3":0, "op4":1, "op5":0, "op6":1, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":6, "score_a":4, "score_p":3, "score_d":2, "score_s":2, "programa":2, "final":0.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5361 |
# +-----------+---------------+
# | estado(1) |        0.4639 |
# +-----------+---------------+
# FILA N°: 31 -> P("Estado" | [{"lt":0.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":1, "op3":1, "op4":1, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":9, "score_a":6, "score_p":3, "score_d":3, "score_s":3, "programa":2, "final":0.0}]
# [bnlearn] >Variable Elimination..
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5987 |
# +-----------+---------------+
# | estado(1) |        0.4013 |
# +-----------+---------------+
# FILA N°: 32 -> P("Estado" | [{"lt":2.0, "tt":2.0, "pt":2.0, "game_score":2.0, "op1":0, "op2":0, "op3":0, "op4":0, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":0, "sv6":1, "score":3, "score_a":2, "score_p":1, "score_d":1, "score_s":1, "programa":3, "final":2.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5513 |
# +-----------+---------------+
# | estado(1) |        0.4487 |
# +-----------+---------------+
# FILA N°: 33 -> P("Estado" | [{"lt":2.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":0, "op3":0, "op4":1, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":0, "sv6":0, "score":9, "score_a":5, "score_p":4, "score_d":4, "score_s":2, "programa":3, "final":0.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
#
#
#
# Finding Elimination Order: : : 0it [00:20, ?it/s]
# Finding Elimination Order: : : 0it [00:40, ?it/s]
# 0it [00:10, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5748 |
# +-----------+---------------+
# | estado(1) |        0.4252 |
# +-----------+---------------+
# FILA N°: 34 -> P("Estado" | [{"lt":2.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":0, "op2":0, "op3":0, "op4":0, "op5":1, "op6":0, "sv1":1, "sv2":0, "sv3":0, "sv4":1, "sv5":1, "sv6":0, "score":6, "score_a":3, "score_p":3, "score_d":1, "score_s":2, "programa":4, "final":1.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5804 |
# +-----------+---------------+
# | estado(1) |        0.4196 |
# +-----------+---------------+
# FILA N°: 35 -> P("Estado" | [{"lt":0.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":1, "op3":1, "op4":1, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":9, "score_a":6, "score_p":4, "score_d":2, "score_s":4, "programa":4, "final":0.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6226 |
# +-----------+---------------+
# | estado(1) |        0.3774 |
# +-----------+---------------+
# FILA N°: 36 -> P("Estado" | [{"lt":1.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":1, "op2":1, "op3":0, "op4":0, "op5":0, "op6":1, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":6, "score_a":4, "score_p":1, "score_d":3, "score_s":3, "programa":3, "final":1.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5443 |
# +-----------+---------------+
# | estado(1) |        0.4557 |
# +-----------+---------------+
# FILA N°: 37 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":0, "op2":1, "op3":1, "op4":0, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":1, "sv4":0, "sv5":1, "sv6":1, "score":8, "score_a":4, "score_p":5, "score_d":2, "score_s":3, "programa":2, "final":1.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:10, ?it/s]
# Finding Elimination Order: : : 0it [00:20, ?it/s]
# Finding Elimination Order: : : 0it [00:50, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6226 |
# +-----------+---------------+
# | estado(1) |        0.3774 |
# +-----------+---------------+
# FILA N°: 38 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":1, "op2":1, "op3":1, "op4":0, "op5":0, "op6":1, "sv1":1, "sv2":1, "sv3":1, "sv4":0, "sv5":1, "sv6":1, "score":5, "score_a":2, "score_p":3, "score_d":1, "score_s":2, "programa":3, "final":1.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5716 |
# +-----------+---------------+
# | estado(1) |        0.4284 |
# +-----------+---------------+
# FILA N°: 39 -> P("Estado" | [{"lt":1.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":0, "op2":1, "op3":0, "op4":0, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":8, "score_a":4, "score_p":4, "score_d":2, "score_s":3, "programa":3, "final":1.0}]
# [bnlearn] >Variable Elimination..
# Finding Elimination Order: : : 0it [00:20, ?it/s]
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5692 |
# +-----------+---------------+
# | estado(1) |        0.4308 |
# +-----------+---------------+
# FILA N°: 42 -> P("Estado" | [{"lt":4.0, "tt":4.0, "pt":4.0, "game_score":4.0, "op1":0, "op2":0, "op3":0, "op4":0, "op5":0, "op6":0, "sv1":0, "sv2":0, "sv3":0, "sv4":0, "sv5":0, "sv6":0, "score":7, "score_a":4, "score_p":2, "score_d":3, "score_s":3, "programa":4, "final":4.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5126 |
# +-----------+---------------+
# | estado(1) |        0.4874 |
# +-----------+---------------+
# FILA N°: 43 -> P("Estado" | [{"lt":1.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":0, "op2":1, "op3":0, "op4":0, "op5":0, "op6":1, "sv1":1, "sv2":1, "sv3":0, "sv4":0, "sv5":1, "sv6":1, "score":10, "score_a":6, "score_p":5, "score_d":2, "score_s":2, "programa":3, "final":0.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5692 |
# +-----------+---------------+
# | estado(1) |        0.4308 |
# +-----------+---------------+
# FILA N°: 44 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":0, "op2":1, "op3":1, "op4":1, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":8, "score_a":6, "score_p":3, "score_d":3, "score_s":3, "programa":4, "final":1.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6313 |
# +-----------+---------------+
# | estado(1) |        0.3687 |
# +-----------+---------------+
# FILA N°: 45 -> P("Estado" | [{"lt":0.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":1, "op3":0, "op4":1, "op5":0, "op6":1, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":11, "score_a":7, "score_p":5, "score_d":4, "score_s":3, "programa":4, "final":0.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:10, ?it/s]
# Finding Elimination Order: : : 0it [00:20, ?it/s]
# Finding Elimination Order: : : 0it [00:50, ?it/s]
# Finding Elimination Order: : : 0it [00:20, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6276 |
# +-----------+---------------+
# | estado(1) |        0.3724 |
# +-----------+---------------+
# FILA N°: 47 -> P("Estado" | [{"lt":2.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":0, "op2":0, "op3":0, "op4":0, "op5":0, "op6":0, "sv1":1, "sv2":0, "sv3":0, "sv4":1, "sv5":0, "sv6":1, "score":9, "score_a":6, "score_p":3, "score_d":3, "score_s":2, "programa":4, "final":0.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6119 |
# +-----------+---------------+
# | estado(1) |        0.3881 |
# +-----------+---------------+
# FILA N°: 48 -> P("Estado" | [{"lt":1.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":1, "op2":1, "op3":0, "op4":0, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":0, "sv5":0, "sv6":1, "score":3, "score_a":2, "score_p":1, "score_d":1, "score_s":2, "programa":3, "final":1.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5655 |
# +-----------+---------------+
# | estado(1) |        0.4345 |
# +-----------+---------------+
# FILA N°: 49 -> P("Estado" | [{"lt":4.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":0, "op2":1, "op3":0, "op4":0, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":0, "sv5":0, "sv6":0, "score":6, "score_a":2, "score_p":4, "score_d":1, "score_s":1, "programa":3, "final":0.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5946 |
# +-----------+---------------+
# | estado(1) |        0.4054 |
# +-----------+---------------+
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# FILA N°: 50 -> P("Estado" | [{"lt":1.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":0, "op2":1, "op3":0, "op4":0, "op5":1, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":0, "score":5, "score_a":2, "score_p":3, "score_d":1, "score_s":1, "programa":4, "final":1.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5944 |
# +-----------+---------------+
# | estado(1) |        0.4056 |
# +-----------+---------------+
# FILA N°: 51 -> P("Estado" | [{"lt":2.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":0, "op2":0, "op3":0, "op4":1, "op5":0, "op6":1, "sv1":1, "sv2":0, "sv3":0, "sv4":1, "sv5":0, "sv6":1, "score":3, "score_a":2, "score_p":1, "score_d":1, "score_s":1, "programa":3, "final":1.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5513 |
# +-----------+---------------+
# | estado(1) |        0.4487 |
# +-----------+---------------+
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:10, ?it/s]
# Finding Elimination Order: : : 0it [00:20, ?it/s]
# Finding Elimination Order: : : 0it [00:50, ?it/s]
# FILA N°: 52 -> P("Estado" | [{"lt":0.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":1, "op3":0, "op4":1, "op5":0, "op6":1, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":5, "score_a":2, "score_p":2, "score_d":2, "score_s":1, "programa":3, "final":0.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5753 |
# +-----------+---------------+
# | estado(1) |        0.4247 |
# +-----------+---------------+
# FILA N°: 53 -> P("Estado" | [{"lt":1.0, "tt":2.0, "pt":2.0, "game_score":2.0, "op1":0, "op2":1, "op3":0, "op4":0, "op5":0, "op6":1, "sv1":1, "sv2":1, "sv3":0, "sv4":0, "sv5":1, "sv6":1, "score":9, "score_a":5, "score_p":5, "score_d":3, "score_s":2, "programa":4, "final":2.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6256 |
# +-----------+---------------+
# | estado(1) |        0.3744 |
# +-----------+---------------+
# FILA N°: 54 -> P("Estado" | [{"lt":1.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":0, "op3":0, "op4":0, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":0, "sv4":0, "sv5":1, "sv6":1, "score":9, "score_a":5, "score_p":4, "score_d":3, "score_s":3, "programa":3, "final":0.0}]
# [bnlearn] >Variable Elimination..
# Finding Elimination Order: : : 0it [00:20, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5068 |
# +-----------+---------------+
# | estado(1) |        0.4932 |
# +-----------+---------------+
# FILA N°: 55 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":1, "op2":1, "op3":0, "op4":0, "op5":1, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":8, "score_a":4, "score_p":4, "score_d":3, "score_s":3, "programa":3, "final":1.0}]
# [bnlearn] >Variable Elimination..
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5525 |
# +-----------+---------------+
# | estado(1) |        0.4475 |
# +-----------+---------------+
# FILA N°: 56 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":1, "op2":0, "op3":1, "op4":0, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":4, "score_a":3, "score_p":1, "score_d":1, "score_s":1, "programa":4, "final":1.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5629 |
# +-----------+---------------+
# | estado(1) |        0.4371 |
# +-----------+---------------+
# FILA N°: 57 -> P("Estado" | [{"lt":2.0, "tt":2.0, "pt":2.0, "game_score":2.0, "op1":0, "op2":0, "op3":0, "op4":0, "op5":0, "op6":1, "sv1":0, "sv2":1, "sv3":0, "sv4":0, "sv5":1, "sv6":1, "score":3, "score_a":3, "score_p":1, "score_d":0, "score_s":1, "programa":4, "final":2.0}]
# [bnlearn] >Variable Elimination..
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5216 |
# +-----------+---------------+
# | estado(1) |        0.4784 |
# +-----------+---------------+
# FILA N°: 58 -> P("Estado" | [{"lt":1.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":0, "op2":1, "op3":0, "op4":0, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":9, "score_a":6, "score_p":4, "score_d":3, "score_s":3, "programa":2, "final":0.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5048 |
# +-----------+---------------+
# | estado(1) |        0.4952 |
# +-----------+---------------+
# FILA N°: 59 -> P("Estado" | [{"lt":0.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":1, "op3":1, "op4":1, "op5":1, "op6":0, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":11, "score_a":7, "score_p":4, "score_d":4, "score_s":3, "programa":3, "final":0.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
#
#
#
#
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:10, ?it/s]
# Finding Elimination Order: : : 0it [00:20, ?it/s]
# Finding Elimination Order: : : 0it [00:50, ?it/s]
# Finding Elimination Order: : : 0it [00:20, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5486 |
# +-----------+---------------+
# | estado(1) |        0.4514 |
# +-----------+---------------+
# FILA N°: 60 -> P("Estado" | [{"lt":1.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":1, "op3":0, "op4":0, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":0, "sv5":1, "sv6":1, "score":9, "score_a":7, "score_p":2, "score_d":4, "score_s":3, "programa":4, "final":0.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6218 |
# +-----------+---------------+
# | estado(1) |        0.3782 |
# +-----------+---------------+
# FILA N°: 61 -> P("Estado" | [{"lt":0.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":0, "op2":1, "op3":0, "op4":1, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":7, "score_a":3, "score_p":4, "score_d":2, "score_s":2, "programa":2, "final":0.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6226 |
# +-----------+---------------+
# | estado(1) |        0.3774 |
# +-----------+---------------+
# FILA N°: 62 -> P("Estado" | [{"lt":1.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":1, "op3":0, "op4":0, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":0, "score":9, "score_a":6, "score_p":4, "score_d":2, "score_s":2, "programa":3, "final":0.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6168 |
# +-----------+---------------+
# | estado(1) |        0.3832 |
# +-----------+---------------+
# FILA N°: 63 -> P("Estado" | [{"lt":1.0, "tt":2.0, "pt":2.0, "game_score":2.0, "op1":1, "op2":1, "op3":0, "op4":0, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":0, "sv5":0, "sv6":1, "score":8, "score_a":5, "score_p":3, "score_d":3, "score_s":3, "programa":1, "final":2.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5048 |
# +-----------+---------------+
# | estado(1) |        0.4952 |
# +-----------+---------------+
# FILA N°: 64 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":0, "op2":1, "op3":0, "op4":1, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":4, "score_a":3, "score_p":2, "score_d":2, "score_s":1, "programa":3, "final":1.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:10, ?it/s]
# Finding Elimination Order: : : 0it [00:20, ?it/s]
# Finding Elimination Order: : : 0it [00:40, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5773 |
# +-----------+---------------+
# | estado(1) |        0.4227 |
# +-----------+---------------+
# FILA N°: 65 -> P("Estado" | [{"lt":0.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":0, "op2":1, "op3":0, "op4":1, "op5":0, "op6":1, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":3, "score_a":3, "score_p":0, "score_d":1, "score_s":1, "programa":4, "final":0.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6511 |
# +-----------+---------------+
# | estado(1) |        0.3489 |
# +-----------+---------------+
# FILA N°: 67 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":1, "op2":1, "op3":1, "op4":0, "op5":0, "op6":1, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":6, "score_a":4, "score_p":2, "score_d":3, "score_s":2, "programa":4, "final":1.0}]
# [bnlearn] >Variable Elimination..
# Finding Elimination Order: : : 0it [00:10, ?it/s]
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6313 |
# +-----------+---------------+
# | estado(1) |        0.3687 |
# +-----------+---------------+
# FILA N°: 68 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":1, "op2":1, "op3":1, "op4":1, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":7, "score_a":5, "score_p":2, "score_d":2, "score_s":3, "programa":3, "final":1.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5773 |
# +-----------+---------------+
# | estado(1) |        0.4227 |
# +-----------+---------------+
# FILA N°: 70 -> P("Estado" | [{"lt":0.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":1, "op3":1, "op4":1, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":5, "score_a":3, "score_p":2, "score_d":2, "score_s":1, "programa":4, "final":0.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
#
#
#
#
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:10, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6226 |
# +-----------+---------------+
# | estado(1) |        0.3774 |
# +-----------+---------------+
# FILA N°: 71 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":0, "op2":1, "op3":0, "op4":1, "op5":0, "op6":1, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":6, "score_a":3, "score_p":3, "score_d":2, "score_s":3, "programa":4, "final":1.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6545 |
# +-----------+---------------+
# | estado(1) |        0.3455 |
# +-----------+---------------+
# FILA N°: 74 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":1, "op2":1, "op3":0, "op4":0, "op5":0, "op6":1, "sv1":1, "sv2":1, "sv3":0, "sv4":0, "sv5":1, "sv6":1, "score":8, "score_a":5, "score_p":4, "score_d":3, "score_s":2, "programa":4, "final":1.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:10, ?it/s]
# Finding Elimination Order: : : 0it [00:20, ?it/s]
# Finding Elimination Order: : : 0it [00:40, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6313 |
# +-----------+---------------+
# | estado(1) |        0.3687 |
# +-----------+---------------+
# FILA N°: 75 -> P("Estado" | [{"lt":1.0, "tt":2.0, "pt":2.0, "game_score":2.0, "op1":1, "op2":0, "op3":0, "op4":1, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":6, "score_a":2, "score_p":3, "score_d":2, "score_s":3, "programa":4, "final":2.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5786 |
# +-----------+---------------+
# | estado(1) |        0.4214 |
# +-----------+---------------+
# FILA N°: 76 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":1, "op2":1, "op3":1, "op4":1, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":7, "score_a":5, "score_p":3, "score_d":2, "score_s":3, "programa":2, "final":1.0}]
# [bnlearn] >Variable Elimination..
# Finding Elimination Order: : : 0it [00:10, ?it/s]
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6226 |
# +-----------+---------------+
# | estado(1) |        0.3774 |
# +-----------+---------------+
# FILA N°: 77 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":1, "op2":1, "op3":1, "op4":1, "op5":1, "op6":0, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":8, "score_a":6, "score_p":3, "score_d":4, "score_s":3, "programa":4, "final":1.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5948 |
# +-----------+---------------+
# | estado(1) |        0.4052 |
# +-----------+---------------+
# FILA N°: 78 -> P("Estado" | [{"lt":1.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":0, "op2":1, "op3":1, "op4":1, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":6, "score_a":3, "score_p":3, "score_d":2, "score_s":2, "programa":4, "final":1.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
#
#
#
#
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:10, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6489 |
# +-----------+---------------+
# | estado(1) |        0.3511 |
# +-----------+---------------+
# FILA N°: 79 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":1, "op2":1, "op3":0, "op4":1, "op5":0, "op6":1, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":7, "score_a":5, "score_p":3, "score_d":3, "score_s":2, "programa":3, "final":1.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5505 |
# +-----------+---------------+
# | estado(1) |        0.4495 |
# +-----------+---------------+
# FILA N°: 80 -> P("Estado" | [{"lt":1.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":0, "op2":1, "op3":0, "op4":0, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":0, "sv5":1, "sv6":1, "score":3, "score_a":2, "score_p":0, "score_d":2, "score_s":1, "programa":4, "final":0.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:10, ?it/s]
# Finding Elimination Order: : : 0it [00:20, ?it/s]
# Finding Elimination Order: : : 0it [00:50, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6489 |
# +-----------+---------------+
# | estado(1) |        0.3511 |
# +-----------+---------------+
# FILA N°: 81 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":1, "op2":1, "op3":0, "op4":1, "op5":0, "op6":1, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":8, "score_a":6, "score_p":3, "score_d":3, "score_s":3, "programa":4, "final":1.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6313 |
# +-----------+---------------+
# | estado(1) |        0.3687 |
# +-----------+---------------+
# FILA N°: 83 -> P("Estado" | [{"lt":0.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":1, "op3":0, "op4":1, "op5":1, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":7, "score_a":4, "score_p":3, "score_d":3, "score_s":3, "programa":2, "final":0.0}]
# [bnlearn] >Variable Elimination..
# Finding Elimination Order: : : 0it [00:20, ?it/s]
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5987 |
# +-----------+---------------+
# | estado(1) |        0.4013 |
# +-----------+---------------+
# FILA N°: 84 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":1, "op2":1, "op3":0, "op4":1, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":10, "score_a":7, "score_p":4, "score_d":4, "score_s":3, "programa":2, "final":1.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5948 |
# +-----------+---------------+
# | estado(1) |        0.4052 |
# +-----------+---------------+
# FILA N°: 87 -> P("Estado" | [{"lt":0.0, "tt":2.0, "pt":2.0, "game_score":2.0, "op1":1, "op2":1, "op3":0, "op4":1, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":4, "score_a":2, "score_p":3, "score_d":1, "score_s":1, "programa":4, "final":2.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6191 |
# +-----------+---------------+
# | estado(1) |        0.3809 |
# +-----------+---------------+
# FILA N°: 88 -> P("Estado" | [{"lt":0.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":1, "op3":1, "op4":1, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":7, "score_a":3, "score_p":4, "score_d":2, "score_s":3, "programa":3, "final":0.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5773 |
# +-----------+---------------+
# | estado(1) |        0.4227 |
# +-----------+---------------+
# FILA N°: 89 -> P("Estado" | [{"lt":0.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":0, "op3":1, "op4":1, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":7, "score_a":4, "score_p":4, "score_d":1, "score_s":2, "programa":3, "final":0.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:10, ?it/s]
# Finding Elimination Order: : : 0it [00:30, ?it/s]
# Finding Elimination Order: : : 0it [00:50, ?it/s]
#
# Finding Elimination Order: : : 0it [01:00, ?it/s]
# 0it [00:10, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5160 |
# +-----------+---------------+
# | estado(1) |        0.4840 |
# +-----------+---------------+
# FILA N°: 90 -> P("Estado" | [{"lt":2.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":0, "op2":0, "op3":0, "op4":0, "op5":0, "op6":0, "sv1":0, "sv2":0, "sv3":0, "sv4":1, "sv5":1, "sv6":0, "score":10, "score_a":6, "score_p":4, "score_d":4, "score_s":3, "programa":2, "final":1.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5177 |
# +-----------+---------------+
# | estado(1) |        0.4823 |
# +-----------+---------------+
# FILA N°: 94 -> P("Estado" | [{"lt":0.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":0, "op2":1, "op3":1, "op4":1, "op5":1, "op6":1, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":8, "score_a":6, "score_p":4, "score_d":1, "score_s":1, "programa":3, "final":1.0}]
# [bnlearn] >Variable Elimination..
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5736 |
# +-----------+---------------+
# | estado(1) |        0.4264 |
# +-----------+---------------+
# FILA N°: 95 -> P("Estado" | [{"lt":1.0, "tt":1.0, "pt":1.0, "game_score":1.0, "op1":0, "op2":0, "op3":0, "op4":0, "op5":0, "op6":0, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":7, "score_a":4, "score_p":4, "score_d":2, "score_s":2, "programa":4, "final":1.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.6119 |
# +-----------+---------------+
# | estado(1) |        0.3881 |
# +-----------+---------------+
# FILA N°: 97 -> P("Estado" | [{"lt":0.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":0, "op2":1, "op3":1, "op4":0, "op5":0, "op6":1, "sv1":1, "sv2":1, "sv3":1, "sv4":1, "sv5":1, "sv6":1, "score":9, "score_a":5, "score_p":4, "score_d":3, "score_s":3, "programa":3, "final":0.0}]
# [bnlearn] >Variable Elimination..
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.5505 |
# +-----------+---------------+
# | estado(1) |        0.4495 |
# +-----------+---------------+
# FILA N°: 98 -> P("Estado" | [{"lt":1.0, "tt":0.0, "pt":0.0, "game_score":0.0, "op1":1, "op2":0, "op3":0, "op4":0, "op5":0, "op6":1, "sv1":1, "sv2":1, "sv3":0, "sv4":1, "sv5":1, "sv6":1, "score":11, "score_a":7, "score_p":5, "score_d":3, "score_s":3, "programa":1, "final":0.0}]
# [bnlearn] >Variable Elimination..
# +-----------+---------------+
# | estado    |   phi(estado) |
# +===========+===============+
# | estado(0) |        0.4651 |
# +-----------+---------------+
# | estado(1) |        0.5349 |
# +-----------+---------------+
# RESULTADOS DEL ENTRENAMIENTO CON SOBREMUESTREO:
# ===============================================
# (TRAIN) Fold 1 Accuracy          : 0.7974683544303798
# (TRAIN) Fold 1 Balanced Accuracy : 0.7986486486486486
# (TRAIN) Fold 1 Precision Score   : 0.9344214967799245
# (TRAIN) Fold 1 Recall Score      : 0.7974683544303798
# (TRAIN) Fold 1 ROC AUC           : 0.5969298245614035
# (TRAIN) Fold 1 Class Ratio       : 0.24050632911392406
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-8-1b23768264cf> in <module>
#      40     file.write('RESULTADOS DEL ENTRENAMIENTO CON SOBREMUESTREO:' + os.linesep)
#      41     file.write('===============================================' + os.linesep)
# ---> 42     file.write('(TRAIN) Fold', str(fold_no), 'Accuracy          :', accuracy_score(lista_train, train.loc[:, 'estado']) + os.linesep)
#      43     file.write('(TRAIN) Fold', str(fold_no), 'Balanced Accuracy :', balanced_accuracy_score(lista_train, train.loc[:, 'estado']) + os.linesep)
#      44     file.write('(TRAIN) Fold', str(fold_no), 'Precision Score   :', precision_score(lista_train, train.loc[:, 'estado'], average='weighted') + os.linesep)
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U32'), dtype('<U32')) -> dtype('<U32')
